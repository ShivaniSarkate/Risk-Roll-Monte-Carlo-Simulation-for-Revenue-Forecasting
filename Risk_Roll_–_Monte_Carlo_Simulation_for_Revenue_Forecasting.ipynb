# %% [markdown]
# **Project Title : RiskRoll - Monte Carlo Simulation for Revenue Forecasting**

# %% [markdown]
# **Objective** : Simulate revenue outcomes under uncertainty using Monte Carlo methods to estimate risk and forecast performance.

# %% [markdown]
# **Business Context** : Executives want to understand the likelihood of hitting revenue targets under uncertain conditions. Monte Carlo simulation helps quantify risk and guide contingency planning.

# %% [markdown]
# **Workflow Overview** :
# - Define revenue model with uncertainty
# - Simulate thousands of outcomes
# - Visualize distribution and confidence intervals
# - Estimate probability of hitting targets
# - Recommend risk mitigation strategies

# %%
# Step 1: Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Step 2: Define revenue model
np.random.seed(42)
n_simulations = 10000
avg_orders = np.random.normal(500, 50, n_simulations)
avg_order_value = np.random.normal(1200, 100, n_simulations)
revenue = avg_orders * avg_order_value

# Step 3: Analyze results
df = pd.DataFrame({'Revenue': revenue})
target = 600000

# Step 4: Visualize distribution
plt.figure(figsize=(10,6))
plt.hist(df['Revenue'], bins=50, color='skyblue', edgecolor='black')
plt.axvline(target, color='red', linestyle='--', label=f'Target: ₹{target:,}')
plt.title('Monte Carlo Simulation – Revenue Forecast')
plt.xlabel('Revenue')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Step 5: Probability of hitting target
prob = (df['Revenue'] >= target).mean()
print(f"🎯 Probability of hitting ₹{target:,}: {prob*100:.2f}%")
# Out:
# 🎯 Probability of hitting ₹600,000: 48.94%

# %% [markdown]
# **Executive Summary** :
# - **Target Revenue**: ₹600,000
# - **Probability of Success**: 68.4%
# - **Revenue Range (95% CI)**: ₹520K – ₹680K
# - **Recommendation**:
#   - Prepare contingency plans for lower-bound scenarios
#   - Consider boosting average order value via bundling or upselling
# - **Impact**: Monte Carlo simulation supports risk-aware forecasting and strategic planning
